# %%
import numpy as np
import pandas as pd
n= 100
df=pd.DataFrame(pd.read_csv("Analytics_COVID_Data.csv"))
import matplotlib.pyplot as plt
import plotly.offline as py
from plotly.offline import iplot
from plotly.graph_objs import Scatter
py.init_notebook_mode(connected=True)

#df1 = df.copy()
df.dropna()
df.sample(n, axis='rows')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#       Person_ID  Status    Level    Condition   Directive Residency_Status  \
# 8460  8927016.0  Closed  Student     Exposure  Quarantine       Off-Campus
# 9765  9083949.0  Closed  Student      COVID +   Isolation        On-Campus
# 9825  9108750.0  Closed  Student     Exposure  Quarantine        On-Campus
# 9667  9069620.0  Closed  Student      COVID +   Isolation       Off-Campus
# ...

# %%
df.head()
n=50
df.set_index("Condition")
df.set_index("Residency_Status")
data = df.head(n=20)
#df.sample(n)
df.sample(n,axis='rows')





x='Residency_Status'
y='Condition'
data["x"] = [i for i in range(20)]
data["y"]= [i for i in range(20,410,20)]
# Plot

plt.scatter(x = 'Residency_Status', y="Condition", data=data ,color='#114a31',s = 25, alpha= 0.8)


plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Out:
# [3503 3504 3505 ... 6736 6737 6738] [   0    1    2 ... 2288 2289 2290]

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-41ee04610e83> in <module>()
#       1 df1 = df.copy()
#       2 df1.dropna()
# ----> 3 df.enc()
#       4
#       5 df = df['Condition'].astype(int)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'enc'
